# %%
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import average, dendrogram
from scipy.spatial.distance import pdist, squareform

# %%
df = pd.read_csv("../Fold-change/Resultados-Fold-Change/GSE147507/fold_change_genes_1_GSE147507.csv")
df.index = df['Unnamed: 0']
df.drop(columns = ['Unnamed: 0'], inplace=True)
df.index.names = ['Genes']

# %%
df
# Out:
#         fold-change Series1  fold-change Series2  fold-change Series5  \
# Genes
# DUOX1             -0.167938             0.130372             0.000000
# ADAR               0.182160             0.685738             0.254281
# ANXA1              0.289965             0.346207            -0.089897
# ANXA2              0.170070             0.026337            -0.072759
# BST2               1.190147             2.568283            -0.957537
# ...                     ...                  ...                  ...
# RAN                0.185871             0.106573            -0.058374
# NLRX1              0.063941            -0.013113            -0.041587
# P2RY6              1.031749            -0.137964            -0.077963
# PTPN11             0.006357             0.200800             0.697495
# GSK3B             -0.158921             0.119446             0.787492
#
#         fold-change Series6  fold-change Series7  \
# Genes
# DUOX1              0.000000             3.680230
# ADAR               0.157392             1.984468
# ANXA1             -0.876357            -0.050257
# ANXA2             -1.306351            -0.030658
# BST2              -0.907026             4.311469
# ...                     ...                  ...
# RAN                0.080260            -0.165435
# NLRX1              0.408132             0.764204
# P2RY6             -0.458964             3.319633
# PTPN11            -0.163699             0.557025
# GSK3B              0.888724             0.900573
#
#         fold-change Series9 NHBE_IFNB_4h  fold-change Series9 NHBE_IFNB_6h  \
# Genes
# DUOX1                          -0.600170                         -0.748791
# ADAR                            1.259580                          1.938170
# ANXA1                          -0.615062                         -0.394590
# ANXA2                           0.300406                          0.230683
# BST2                            3.408031                          4.421805
# ...                                  ...                               ...
# RAN                             0.163854                          0.346439
# NLRX1                          -0.664153                         -0.895840
# P2RY6                           0.606290                          0.228773
# PTPN11                          0.478418                          0.988568
# GSK3B                           1.151247                          1.325037
#
#         fold-change Series9 NHBE_IFNB_12h  fold-change Series15  \
# Genes
# DUOX1                           -0.925573              1.236842
# ADAR                             1.853142              1.128040
# ANXA1                           -0.663930             -1.121906
# ANXA2                            0.132907             -0.304444
# BST2                             6.067895             -0.215897
# ...                                   ...                   ...
# RAN                              0.300089             -1.042670
# NLRX1                           -1.138120                   inf
# P2RY6                           -0.744362              1.017637
# PTPN11                           0.541719             -1.236990
# GSK3B                            0.208565             -0.335228
#
#         fold-change Series16 A549-ACE2_SARS-CoV-2  \
# Genes
# DUOX1                                    2.161675
# ADAR                                     1.876016
# ANXA1                                   -0.625737
# ANXA2                                   -0.903687
# BST2                                     3.682049
# ...                                           ...
# RAN                                      0.726380
# NLRX1                                    0.211258
# P2RY6                                    0.218833
# PTPN11                                   0.470489
# GSK3B                                    2.097162
#
#         fold-change Series16 A549-ACE2_SARS-CoV-2_Rux
# Genes
# DUOX1                                        2.431973
# ADAR                                         0.869342
# ANXA1                                       -0.592316
# ANXA2                                       -0.722669
# BST2                                         0.597904
# ...                                               ...
# RAN                                          0.905294
# NLRX1                                        0.718703
# P2RY6                                       -0.650814
# PTPN11                                       0.659089
# GSK3B                                        2.305324
#
# [338 rows x 11 columns]

# %%
# Replace infinite updated data with nan
df.replace([np.inf, -np.inf], np.nan, inplace=True)
# Drop rows with NaN
df.dropna(inplace=True)
points = df['fold-change Series1']

# %%
# convert the list to a 2-dimensional array
points_array = np.array(points).reshape(-1, 1)

# calculate the pairwise distances between the points
distances = pdist(points_array)

# convert the distance vector to a distance matrix
matrix = squareform(distances)

# %%
# perform UPGMA clustering
linkage_matrix = average(distances)

# %%
# plot the dendrogram
dend = dendrogram(linkage_matrix)
